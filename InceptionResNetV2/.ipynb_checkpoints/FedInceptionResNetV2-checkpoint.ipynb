# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report

# Define the InceptionResNetV2 model
def create_inceptionresnetv2_model():
    base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(64, activation='relu')(x)
    predictions = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    
    for layer in base_model.layers:
        layer.trainable = False
    
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Define a function to load data from a local dataset
def load_data(client_folder):
    data = []
    labels = []
    for category in ['cataract', 'normal']:
        category_folder = os.path.join(client_folder, category)
        label = 1 if category == 'cataract' else 0
        for image_file in os.listdir(category_folder):
            image_path = os.path.join(category_folder, image_file)
            img = tf.io.read_file(image_path)
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, [128, 128])
            img = img / 255.0
            data.append(img.numpy())
            labels.append(label)
    return np.array(data), np.array(labels)

# Define a custom federated averaging algorithm
def custom_federated_averaging(global_model, local_model):
    for global_layer, local_layer in zip(global_model.layers, local_model.layers):
        weights = [0.5 * (global_w + local_w) for global_w, local_w in zip(global_layer.get_weights(), local_layer.get_weights())]
        global_layer.set_weights(weights)
    return global_model

# Define a function to perform local training
def train_local_model(local_model, data, labels):
    local_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = local_model.fit(data, labels, epochs=10, batch_size=32)
    return local_model, history

# Main federated learning process
if __name__ == '__main__':
    # Define the client folders
    client_folders = ['ds1', 'ds2', 'ds3', 'ds4', 'ds5']

    # Set the current directory
    current_dir = os.getcwd()

    # Create local models
    local_models = [create_inceptionresnetv2_model() for _ in client_folders]

    # Train local models
    for i, client_folder in enumerate(client_folders):
        client_folder_path = os.path.join(current_dir, client_folder)
        data, labels = load_data(client_folder_path)
        local_models[i], history = train_local_model(local_models[i], data, labels)

        # Plot accuracy graph for each local model
        plt.plot(history.history['accuracy'], label=f'Local Model {i+1}')

    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    # Initialize global model
    global_model = create_inceptionresnetv2_model()

    # Update global model with local models
    for local_model in local_models:
        global_model = custom_federated_averaging(global_model, local_model)

    # Save models
    global_model.save('global_model.h5')

    for i, local_model in enumerate(local_models):
        local_model.save(f'local_model_ds{i+1}.h5')

    # Load global model and compile it
    global_model = tf.keras.models.load_model('global_model.h5')
    global_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

    # Evaluate global model on the entire dataset
    global_data, global_labels = [], []
    for client_folder in client_folders:
        client_folder_path = os.path.join(current_dir, client_folder)
        data, labels = load_data(client_folder_path)
        global_data.extend(data)
        global_labels.extend(labels)

    global_data, global_labels = np.array(global_data), np.array(global_labels)
    global_accuracy = global_model.evaluate(global_data, global_labels)[1]
    print(f'Global Model Accuracy: {global_accuracy * 100:.2f}%')

    # Calculate and display confusion matrix
    predictions = (global_model.predict(global_data) > 0.5).astype('int32')
    cm = confusion_matrix(global_labels, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Cataract'])
    disp.plot(cmap=plt.cm.Blues)
    plt.show()

    # Additional Evaluation Metrics
    predictions = (global_model.predict(global_data) > 0.5).astype('int32')
    report = classification_report(global_labels, predictions, target_names=['Normal', 'Cataract'], zero_division=1)
    print("Classification Report:")
    print(report)
# Out:
# Epoch 1/10
# 13/13 [==============================] - 79s 2s/step - loss: 0.7193 - accuracy: 0.6778
# Epoch 2/10
# 13/13 [==============================] - 30s 2s/step - loss: 0.3404 - accuracy: 0.8557
# Epoch 3/10
# 13/13 [==============================] - 30s 2s/step - loss: 0.2532 - accuracy: 0.8892
# Epoch 4/10
# 13/13 [==============================] - 35s 3s/step - loss: 0.2211 - accuracy: 0.8943
# Epoch 5/10
# 13/13 [==============================] - 32s 2s/step - loss: 0.2018 - accuracy: 0.9046
# Epoch 6/10
# 13/13 [==============================] - 33s 3s/step - loss: 0.1854 - accuracy: 0.9098
# Epoch 7/10
# 13/13 [==============================] - 34s 3s/step - loss: 0.1766 - accuracy: 0.9201
# Epoch 8/10
# 13/13 [==============================] - 34s 3s/step - loss: 0.1785 - accuracy: 0.9201
# Epoch 9/10
# 13/13 [==============================] - 39s 3s/step - loss: 0.1625 - accuracy: 0.9381
# Epoch 10/10
# 13/13 [==============================] - 31s 2s/step - loss: 0.1807 - accuracy: 0.9124
# Epoch 1/10
# 15/15 [==============================] - 84s 3s/step - loss: 0.4484 - accuracy: 0.7879
# Epoch 2/10
# 15/15 [==============================] - 30s 2s/step - loss: 0.2324 - accuracy: 0.9026
# Epoch 3/10
# 15/15 [==============================] - 27s 2s/step - loss: 0.1886 - accuracy: 0.9242
# Epoch 4/10
# 15/15 [==============================] - 28s 2s/step - loss: 0.1661 - accuracy: 0.9286
# Epoch 5/10
# 15/15 [==============================] - 26s 2s/step - loss: 0.1483 - accuracy: 0.9307
# Epoch 6/10
# 15/15 [==============================] - 32s 2s/step - loss: 0.1374 - accuracy: 0.9394
# Epoch 7/10
# 15/15 [==============================] - 34s 2s/step - loss: 0.1262 - accuracy: 0.9459
# Epoch 8/10
# 15/15 [==============================] - 27s 2s/step - loss: 0.1177 - accuracy: 0.9589
# Epoch 9/10
# 15/15 [==============================] - 27s 2s/step - loss: 0.1086 - accuracy: 0.9610
# Epoch 10/10
# 15/15 [==============================] - 28s 2s/step - loss: 0.1046 - accuracy: 0.9697
# Epoch 1/10
# 12/12 [==============================] - 51s 2s/step - loss: 0.5250 - accuracy: 0.7346
# Epoch 2/10
# 12/12 [==============================] - 22s 2s/step - loss: 0.2921 - accuracy: 0.8994
# Epoch 3/10
# 12/12 [==============================] - 21s 2s/step - loss: 0.2605 - accuracy: 0.8966
# Epoch 4/10
# 12/12 [==============================] - 21s 2s/step - loss: 0.2208 - accuracy: 0.9218
# Epoch 5/10
# 12/12 [==============================] - 22s 2s/step - loss: 0.2017 - accuracy: 0.9330
# Epoch 6/10
# 12/12 [==============================] - 23s 2s/step - loss: 0.1960 - accuracy: 0.9330
# Epoch 7/10
# 12/12 [==============================] - 21s 2s/step - loss: 0.1847 - accuracy: 0.9330
# Epoch 8/10
# 12/12 [==============================] - 23s 2s/step - loss: 0.2181 - accuracy: 0.9162
# Epoch 9/10
# 12/12 [==============================] - 21s 2s/step - loss: 0.1641 - accuracy: 0.9497
# Epoch 10/10
# 12/12 [==============================] - 21s 2s/step - loss: 0.1549 - accuracy: 0.9525
# Epoch 1/10
# 8/8 [==============================] - 45s 2s/step - loss: 0.7244 - accuracy: 0.6062
# Epoch 2/10
# 8/8 [==============================] - 14s 2s/step - loss: 0.3316 - accuracy: 0.8451
# Epoch 3/10
# 8/8 [==============================] - 13s 2s/step - loss: 0.2123 - accuracy: 0.9159
# Epoch 4/10
# 8/8 [==============================] - 14s 2s/step - loss: 0.1782 - accuracy: 0.9336
# Epoch 5/10
# 8/8 [==============================] - 14s 2s/step - loss: 0.1475 - accuracy: 0.9469
# Epoch 6/10
# 8/8 [==============================] - 14s 2s/step - loss: 0.1335 - accuracy: 0.9513
# Epoch 7/10
# 8/8 [==============================] - 14s 2s/step - loss: 0.1191 - accuracy: 0.9558
# Epoch 8/10
# 8/8 [==============================] - 14s 2s/step - loss: 0.1098 - accuracy: 0.9602
# Epoch 9/10
# 8/8 [==============================] - 13s 2s/step - loss: 0.1012 - accuracy: 0.9602
# Epoch 10/10
# 8/8 [==============================] - 13s 2s/step - loss: 0.0922 - accuracy: 0.9602
# Epoch 1/10
# 6/6 [==============================] - 69s 1s/step - loss: 0.7424 - accuracy: 0.6413
# Epoch 2/10
# 6/6 [==============================] - 11s 2s/step - loss: 0.5092 - accuracy: 0.7772
# Epoch 3/10
# 6/6 [==============================] - 10s 1s/step - loss: 0.3071 - accuracy: 0.8804
# Epoch 4/10
# 6/6 [==============================] - 11s 2s/step - loss: 0.2673 - accuracy: 0.9185
# Epoch 5/10
# 6/6 [==============================] - 10s 2s/step - loss: 0.2007 - accuracy: 0.9457
# Epoch 6/10
# 6/6 [==============================] - 9s 1s/step - loss: 0.1688 - accuracy: 0.9511
# Epoch 7/10
# 6/6 [==============================] - 11s 2s/step - loss: 0.1445 - accuracy: 0.9457
# Epoch 8/10
# 6/6 [==============================] - 9s 2s/step - loss: 0.1248 - accuracy: 0.9565
# Epoch 9/10
# 6/6 [==============================] - 10s 2s/step - loss: 0.1070 - accuracy: 0.9674
# Epoch 10/10
# 6/6 [==============================] - 12s 2s/step - loss: 0.0957 - accuracy: 0.9674
# 51/51 [==============================] - 120s 2s/step - loss: 0.4808 - accuracy: 0.7967
# Global Model Accuracy: 79.67%
# 51/51 [==============================] - 112s 2s/step
# 51/51 [==============================] - 96s 2s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.77      0.98      0.87      1074
#     Cataract       0.93      0.43      0.59       544
#
#     accuracy                           0.80      1618
#    macro avg       0.85      0.71      0.73      1618
# weighted avg       0.82      0.80      0.77      1618
